# %% [markdown]
# ## Exercícios
# Para este conjunto de exercícios usaremos um dataset que mostra a produção mensal média de leite por vaca de uma fazenda no período entre Janeiro de 1962 e Dezembro de 1975. A unidade utilizada é pound. ( 1 pound =~ 0,5 kg =~ 0,5 litro)

# %%
import pandas as pd
# %matplotlib inline

df = pd.read_csv('monthly_milk_production.csv', encoding='utf8')
title = "Monthly milk production: pounds per cow. Jan '62 - Dec '75"

print(len(df))
print(df.head())
# Out:
# 168
#       Date  Production
# 0  1962-01         589
# 1  1962-02         561
# 2  1962-03         640
# 3  1962-04         656
# 4  1962-05         727

# %% [markdown]
# Portanto df tem 168 registros e duas colunas.

# %% [markdown]
# ### Questão 1
# Qual é o tipo de dado da coluna Date?

# %%
df.dtypes
# Out:
# Date          object
# Production     int64
# dtype: object

# %% [markdown]
# ### Questão 2
# Modifique a coluna Date para o formato datetime.

# %%
df["Date"] = pd.to_datetime(df["Date"])
df.dtypes
# Out:
# Date          datetime64[ns]
# Production             int64
# dtype: object

# %% [markdown]
# ### Questão 3
# Ajuste a coluna Date de forma que ela seja o novo índice do dataframe.

# %%
df.set_index("Date" , inplace=True)
df.head()
# Out:
#             Production
# Date
# 1962-01-01         589
# 1962-02-01         561
# 1962-03-01         640
# 1962-04-01         656
# 1962-05-01         727

# %% [markdown]
# ### Questão 4
# Plote o DataFrame utilizando um line plot simples. O que você nota sobre esse gráfico?

# %%
df.plot(figsize=(12,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Questão 5
# Adicione uma coluna chamada 'Month' (Mês) que obtém o mês correspondente do índice
#
# BONUS: \
# Tente obter o nome do mês ao invés do número.

# %%
from matplotlib import dates
df["Month"] = df.index.month
df.head()
# Out:
#             Production  Month
# Date
# 1962-01-01         589      1
# 1962-02-01         561      2
# 1962-03-01         640      3
# 1962-04-01         656      4
# 1962-05-01         727      5

# %%
df["Month"] = df.index.strftime("%B")

df.head()
# Out:
#             Production     Month
# Date
# 1962-01-01         589   January
# 1962-02-01         561  February
# 1962-03-01         640     March
# 1962-04-01         656     April
# 1962-05-01         727       May

# %% [markdown]
# ### Questão 6
# Exiba um BoxPlot que agrupe a produção pelo Mês (Month)

# %%
df.boxplot(by="Month" , figsize=(12,5))
# Out:
# <Axes: title={'center': 'Production'}, xlabel='[Month]'>
